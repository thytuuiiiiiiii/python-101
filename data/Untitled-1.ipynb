# %%
pip install wget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
wget .download("")https://github.com/tku-peiyucheng/python101/blob/main/scores.csv
# Out:
#   Cell In[46], line 1
#     wget .download("")https://github.com/tku-peiyucheng/python101/blob/main/scores.csv
#                       ^
# SyntaxError: invalid syntax

# %%
# %%writefile hi.py
print("hi")
# Out:
# Overwriting hi.py

# %%
import numpy as np

na = np.genfromtxt('scores.csv',delimiter=',', skip_header= 1)
print(na.shape)

na
# Out:
# (30, 4)
# array([[ 1., 87., 85., 82.],
#        [ 2., 92., 87., 90.],
#        [ 3., 80., 91., 87.],
#        [ 4., 78., 82., 95.],
#        [ 5., 88., 89., 90.],
#        [ 6., 82., 87., 88.],
#        [ 7., 90., 92., 82.],
#        [ 8., 87., 80., 90.],
#        [ 9., 95., 78., 87.],
#        [10., 90., 88., 95.],
#        [11., 88., 89., 75.],
#        [12., 82., 91., 66.],
#        [13., 90., 82., 87.],
#        [14., 87., 89., 92.],
#        [15., 95., 87., 80.],
#        [16., 90., 92., 78.],
#        [17., 82., 80., 88.],
#        [18., 90., 78., 93.],
#        [19., 67., 87., 95.],
#        [20., 91., 82., 88.],
#        [21., 82., 81., 82.],
#        [22., 79., 87., 90.],
#        [23., 87., 92., 87.],
#        [24., 92., 82., 95.],
#        [25., 80., 90., 78.],
#        [26., 78., 76., 91.],
#        [27., 66., 90., 82.],
#        [28., 89., 77., 89.],
#        [29., 87., 95., 87.],
#        [30., 73., 90., 92.]])

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

plt.plot([9,9,2,9,6,7,5,6,7,7],[9,4,9,2,9,2,9,2,7,1],'bx')

plt.legend(('Orange','Lemons'),loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[0,0.3,0.6,0.9],'gx')
plt.plot([1,2,3,4],[0,0.3,0.6,0.9],'r-')
plt.axis([0,5,0,1])
plt.ylabel('Y')
plt.xlabel('p')
plt.legend(('price','passenger'),loc='upper right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
pip install sklearn
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
# ...

# %%
from sklearn import linear_model

import pandas as pd

dataframe = pd.read_fwf('brain_body.txt')

x_values = dataframe[['Body']]
y_values = dataframe[['Brain']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[74], line 5
#       1 from sklearn import linear_model
#       3 import pandas as pd
# ----> 5 dataframe = pd.read_fwf('brain_body.txt')
#       7 x_values = dataframe[['Body']]
#       8 y_values = dataframe[['Brain']]
#
# File c:\Users\TKU-STAFF\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1393, in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, dtype_backend, **kwds)
#    1391 check_dtype_backend(dtype_backend)
#    1392 kwds["dtype_backend"] = dtype_backend
# -> 1393 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\TKU-STAFF\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %%
from sklearn import linear_model

import pandas as pd

dataframe = pd.read_fwf('brain_body.txt')

x_values = dataframe[['Body']]
y_values = dataframe[['Brain']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[67], line 5
#       1 from sklearn import linear_model
#       3 import pandas as pd
# ----> 5 dataframe = pd.read_fwf('brain_body.txt')
#       7 x_values = dataframe[['Body']]
#       8 y_values = dataframe[['Brain']]
#
# File c:\Users\TKU-STAFF\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1393, in read_fwf(filepath_or_buffer, colspecs, widths, infer_nrows, dtype_backend, **kwds)
#    1391 check_dtype_backend(dtype_backend)
#    1392 kwds["dtype_backend"] = dtype_backend
# -> 1393 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\TKU-STAFF\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
# ...

# %%
body_reg =  linear_model.LinearRegression()

body_reg.fix(x_values,y_values)

print(body_reg.predict(pd.DataFrame(data=[[170]])))

plt.scatter(x_values,y_values)

plt.plot(x_values,pre)
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 3
#       1 body_reg =  linear_model.LinearRegression()
# ----> 3 body_reg.fix(x_values,y_values)
#       5 print(body_reg.predict(pd.DataFrame(data=[[170]])))
#       7 plt.scatter(x_values,y_values)
#
# AttributeError: 'LinearRegression' object has no attribute 'fix'

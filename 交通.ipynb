# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_csv = pd.read_csv("4c8f59a2-59c4-4204-979b-f2ac824d996b.csv")

# %%
df_csv
# Out:
#                                違反項目    汽車逕舉   汽車攔停  逾250cc大型重型機車逕舉  \
# 0                                合計  379194  40222            4260
# 1                           未領用牌照行駛       0      0               0
# 2                          拼裝車輛違規行駛       0      7               0
# 3                     使用偽造、變造或矇領之牌照       0      6               0
# 4                        使用吊銷、註銷之牌照       2    174               0
# ..                              ...     ...    ...             ...
# 231                     因待售車放置道路而移置       0      0               0
# 232                       肇事車輛移置、扣留       0      0               0
# 233      禁止通行、禁止其行駛、禁止其駕駛者，移置保管其車輛。       0      0               0
# 234       十四歲以上未成年人，未領有駕駛執照駕駛小型車或機車       0      1               0
# 235  十四歲以上未成年人，用偽、變造或矇領駕駛執照駕駛小型車或機車       0      0               0
#
#      逾250cc大型重型機車攔停  250cc以下機車逕舉  250cc以下機車攔停  動力機械
# 0               449       301412        90956  1675
# 1                 0            0            1     0
# ...

# %%
df_csv.plot(x='x_column',y = 'y_column')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TKU-STAFF\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x_column'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_csv.plot(x='x_column',y = 'y_column')
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rc('font', family='Microsoft JhengHei')
from io import StringIO

# 定義數據字符串
data_str = """
違反項目 汽車逕舉 汽車攔停 逾250cc大型重型機車逕舉 逾250cc大型重型機車攔停 250cc以下機車逕舉 250cc以下機車攔停 動力機械
合計 379194 40222 4260 449 301412 90956 1675
未領用牌照行駛 0 0 0 0 0 1 0
拼裝車輛違規行駛 0 7 0 0 0 13 2
使用偽造、變造或矇領之牌照 0 6 0 0 0 1 0
使用吊銷、註銷之牌照 2 174 0 4 0 202 0
因待售車放置道路而移置 0 0 0 0 0 0 0
肇事車輛移置、扣留 0 0 0 0 0 0 0
禁止通行、禁止其行駛、禁止其駕駛者，移置保管其車輛。 0 0 0 0 0 0 0
十四歲以上未成年人，未領有駕駛執照駕駛小型車或機車 0 1 0 0 0 4 0
十四歲以上未成年人，用偽、變造或矇領駕駛執照駕駛小型車或機車 0 0 0 0 0 0 0
"""

# 使用 StringIO 將字符串轉換成文件對象
data = StringIO(data_str)

# 使用 pandas 讀取這些數據
df = pd.read_csv(data, delim_whitespace=True)

# 設置中文字體
plt.rcParams['font.sans-serif'] = ['Taipei Sans TC Beta'] # 適用於本地環境安裝的中文字體
plt.rcParams['axes.unicode_minus'] = False

# 繪製圖表
ax = df.plot(kind='bar', x='違反項目', figsize=(15, 7), width=0.8)
plt.title('違規項目統計')
plt.xlabel('違反項目')
plt.ylabel('次數')
plt.xticks(rotation=45, ha='right')
plt.legend(title='交通工具類型')

# 顯示圖表
plt.tight_layout()
plt.show()
